# %%
import pandas as pd
import matplotlib.pyplot as plt
file = pd.read_csv('fandango_score_comparison.csv')
file.head(20)
# Out:
#                                               FILM  RottenTomatoes  \
# 0                   Avengers: Age of Ultron (2015)              74
# 1                                Cinderella (2015)              85
# 2                                   Ant-Man (2015)              80
# 3                           Do You Believe? (2015)              18
# 4                    Hot Tub Time Machine 2 (2015)              14
# 5                         The Water Diviner (2015)              63
# 6                            Irrational Man (2015)              42
# 7                                  Top Five (2014)              86
# 8                     Shaun the Sheep Movie (2015)              99
# 9                              Love & Mercy (2015)              89
# 10               Far From The Madding Crowd (2015)              84
# 11                                Black Sea (2015)              82
# 12                                Leviathan (2014)              99
# 13                                 Unbroken (2014)              51
# 14                       The Imitation Game (2014)              90
# 15                                  Taken 3 (2015)               9
# 16                                    Ted 2 (2015)              46
# 17                                 Southpaw (2015)              59
# 18  Night at the Museum: Secret of the Tomb (2014)              50
# 19                                   Pixels (2015)              17
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 0                    86          66              7.1   7.8             5.0
# 1                    80          67              7.5   7.1             5.0
# 2                    90          64              8.1   7.8             5.0
# 3                    84          22              4.7   5.4             5.0
# 4                    28          29              3.4   5.1             3.5
# 5                    62          50              6.8   7.2             4.5
# 6                    53          53              7.6   6.9             4.0
# 7                    64          81              6.8   6.5             4.0
# 8                    82          81              8.8   7.4             4.5
# 9                    87          80              8.5   7.8             4.5
# 10                   77          71              7.5   7.2             4.5
# 11                   60          62              6.6   6.4             4.0
# 12                   79          92              7.2   7.7             4.0
# 13                   70          59              6.5   7.2             4.5
# 14                   92          73              8.2   8.1             5.0
# 15                   46          26              4.6   6.1             4.5
# 16                   58          48              6.5   6.6             4.5
# 17                   80          57              8.2   7.8             5.0
# 18                   58          47              5.8   6.3             4.5
# 19                   54          27              5.3   5.6             4.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 0                    4.5     3.70          4.30  ...       3.90
# 1                    4.5     4.25          4.00  ...       3.55
# 2                    4.5     4.00          4.50  ...       3.90
# 3                    4.5     0.90          4.20  ...       2.70
# 4                    3.0     0.70          1.40  ...       2.55
# 5                    4.0     3.15          3.10  ...       3.60
# 6                    3.5     2.10          2.65  ...       3.45
# 7                    3.5     4.30          3.20  ...       3.25
# 8                    4.0     4.95          4.10  ...       3.70
# 9                    4.0     4.45          4.35  ...       3.90
# 10                   4.0     4.20          3.85  ...       3.60
# 11                   3.5     4.10          3.00  ...       3.20
# 12                   3.5     4.95          3.95  ...       3.85
# 13                   4.1     2.55          3.50  ...       3.60
# 14                   4.6     4.50          4.60  ...       4.05
# 15                   4.1     0.45          2.30  ...       3.05
# 16                   4.1     2.30          2.90  ...       3.30
# 17                   4.6     2.95          4.00  ...       3.90
# 18                   4.1     2.50          2.90  ...       3.15
# 19                   4.1     0.85          2.70  ...       2.80
#
#     RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0             3.5                 4.5                    3.5
# 1             4.5                 4.0                    3.5
# 2             4.0                 4.5                    3.0
# 3             1.0                 4.0                    1.0
# 4             0.5                 1.5                    1.5
# 5             3.0                 3.0                    2.5
# 6             2.0                 2.5                    2.5
# 7             4.5                 3.0                    4.0
# 8             5.0                 4.0                    4.0
# 9             4.5                 4.5                    4.0
# 10            4.0                 4.0                    3.5
# 11            4.0                 3.0                    3.0
# 12            5.0                 4.0                    4.5
# 13            2.5                 3.5                    3.0
# 14            4.5                 4.5                    3.5
# 15            0.5                 2.5                    1.5
# 16            2.5                 3.0                    2.5
# 17            3.0                 4.0                    3.0
# 18            2.5                 3.0                    2.5
# 19            1.0                 2.5                    1.5
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 0                          3.5              4.0                        1330
# 1                          4.0              3.5                         249
# 2                          4.0              4.0                         627
# 3                          2.5              2.5                          31
# 4                          1.5              2.5                          88
# 5                          3.5              3.5                          34
# 6                          4.0              3.5                          17
# 7                          3.5              3.5                         124
# 8                          4.5              3.5                          62
# 9                          4.5              4.0                          54
# 10                         4.0              3.5                          35
# 11                         3.5              3.0                          37
# 12                         3.5              4.0                         145
# 13                         3.5              3.5                         218
# 14                         4.0              4.0                         566
# 15                         2.5              3.0                         240
# 16                         3.5              3.5                         197
# 17                         4.0              4.0                         128
# 18                         3.0              3.0                         103
# 19                         2.5              3.0                         246
#
#     IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 0                 271107           14846                  0.5
# 1                  65709           12640                  0.5
# 2                 103660           12055                  0.5
# 3                   3136            1793                  0.5
# 4                  19560            1021                  0.5
# 5                  39373             397                  0.5
# 6                   2680             252                  0.5
# 7                  16876            3223                  0.5
# 8                  12227             896                  0.5
# 9                   5367             864                  0.5
# 10                 12129             804                  0.5
# 11                 16547             218                  0.5
# 12                 22521              64                  0.5
# 13                 77518            9443                  0.4
# 14                334164            8055                  0.4
# 15                104235            6757                  0.4
# 16                 49102            6437                  0.4
# 17                 23561            5597                  0.4
# 18                 50291            5445                  0.4
# 19                 19521            3886                  0.4
#
# [20 rows x 22 columns]

# %%
film_name = file['FILM']
Metacritic_users = file['Metacritic_user_vote_count']
IMDB_users = file['IMDB_user_vote_count']
Fandango_users = file['Fandango_votes']
Fandango_users.head(2)
# Out:
# 0    14846
# 1    12640
# Name: Fandango_votes, dtype: int64

# %%
plt.figure(figsize= (10,4))
plt.plot(file.loc[:,'FILM'],Fandango_users,color="red", label="Fandango_votes")
plt.plot(file.loc[:,'FILM'],Metacritic_users,color="brown", label="Metacritic_user_vote_count")
plt.plot(file.loc[:,'FILM'],IMDB_users,color = "blue" , label="IMDB_user_vote_counts")
plt.xticks(rotation=90)
plt.grid(linewidth=1)
plt.legend()
plt.xlabel("Names")
plt.ylabel("votes")
plt.title("scores comparison between different online movies websites")
plt.show()

# %%
file = pd.read_excel('report.xlsx')
file.head()
# Out:
#   Departmental Family                       Entity       Date  \
# 0                 DWP  HEALTH AND SAFETY EXECUTIVE 2019-01-11
# 1                 DWP  HEALTH AND SAFETY EXECUTIVE 2019-01-24
# 2                 DWP  HEALTH AND SAFETY EXECUTIVE 2019-01-02
# 3                 DWP  HEALTH AND SAFETY EXECUTIVE 2019-01-02
# 4                 DWP  HEALTH AND SAFETY EXECUTIVE 2019-01-18
#
#         Expense Type             Business Function  \
# 0        Other Costs           Engagement & Policy
# 1              Legal          Chemical Regulations
# 2        Other Costs  Finance & Corporate Services
# 3              Legal              Field Operations
# 4  IS/IT & Telecomms  Finance & Corporate Services
#
#                                  Supplier  Transaction Number  # Amount  \
# 0  ADVENTURE ACTIVITIES LICENSING SERVICE            10000811     58520
# 1             GOVERNMENT LEGAL DEPARTMENT            30000086    130000
# 2           BRITISH STANDARDS INSTITUTION          1043037368     67379
# 3                     LESTER ALDRIDGE LLP          1043037372     69492
# 4                              ULTRIS LTD          1043038166     28800
#
#               Description
# 0           Other Charges
# 1  Law Tribunal And Legal
# 2             Consumables
# 3  Law Tribunal And Legal
# 4                     ICT

# %%
#creating a new file and seperating the data
n_f = file['Expense Type'].value_counts().rename_axis('Expense_Type').reset_index(name='count')
print(n_f)
# Out:
#                     Expense_Type  count
# 0               Accomm & Estates     20
# 1              IS/IT & Telecomms     10
# 2                        Capital      6
# 3                    Other Costs      5
# 4                          Legal      4
# 5  Research & Support - External      3

# %%
n_f.loc[:,"Expense_Type"]
# Out:
# 0                 Accomm & Estates
# 1                IS/IT & Telecomms
# 2                          Capital
# 3                      Other Costs
# 4                            Legal
# 5    Research & Support - External
# Name: Expense_Type, dtype: object

# %%
#creating our pie chart
fig = plt.figure()
y_explode = [0,0,0,0.05,0.1,0.1]
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(n_f.loc[:,"count"],labels=n_f.loc[:,"Expense_Type"],autopct='%.2f',explode=y_explode)
plt.title('HEath and safety expenses')
plt.legend(loc='upper left',prop={'size': 8})

# %%
file = pd.read_csv('movies.csv')
file.head(2)
# Out:
#    year       imdb          title         test clean_test binary    budget  \
# 0  2013  tt1711425  21 &amp; Over       notalk     notalk   FAIL  13000000
# 1  2012  tt1343727       Dredd 3D  ok-disagree         ok   PASS  45000000
#
#      domgross    intgross      code  budget_2013$  domgross_2013$  \
# 0  25682380.0  42195766.0  2013FAIL      13000000      25682380.0
# 1  13414714.0  40868994.0  2012PASS      45658735      13611086.0
#
#    intgross_2013$  period code  decade code
# 0      42195766.0          1.0          1.0
# 1      41467257.0          1.0          1.0

# %%
estimated_budget = file['budget']
final_budget =file['budget_2013$']
final_domgross =file['domgross_2013$']
estimated_domgross =file['domgross']
final_intgross =file['intgross_2013$']
estimated_intgross =file['intgross']

# %%
plt.scatter(final_budget,estimated_budget,color='blue',s=100,label='budget',marker='.')
plt.scatter(final_domgross,final_intgross,color='red',s=100,label='final profits',marker='.')
plt.scatter(estimated_domgross,estimated_intgross,color='green',s=100,label='estimated profits',marker='.')
plt.grid()
plt.xlabel('total_budget')
plt.ylabel('estimated_budget')
plt.legend()
plt.title('budget analysis of movies 2013')
plt.figure(figsize= (6,3))
